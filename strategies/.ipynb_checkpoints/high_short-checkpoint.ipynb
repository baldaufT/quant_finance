# %% [markdown]
# # High-Short Strategy
#
# High_Short is a "Basic Part Strategy" as it normally wouldn't stand alone as a strategy but can be a part of a superior strategy. Furthermore, it is still quite simple and builds therefore a basis on which other (more complex) strategies can be build on.
#
# The Strategy is looking for all time highs and only then, goes short. The theory behind means, that irrational humans tend to sell just because an all time high was reached even though the price would be fair (or not). It only works on indices.

# %%
import numpy as np
import pandas as pd

# %% [markdown]
# Importing the data, which shows for each day of the last 50 years one price. Data was provided by Thomson Reuters (University License) from 19.12.1969 (Index 0) until 13.12.2019 (Index 13044).

# %%
data = pd.read_csv("../data/DAX_DATA/Price_History_daily_50y.csv")
data.plot()

# %%
allTimeHigh = 0
currVal = 0
marge = 0.5 # in percent

# %%
for val in data.itertuples():
    if allTimeHigh * (1 + (marge / 100)) < val[1]:
        allTimeHigh = val[1]
        print(val)
# Out:
# Pandas(Index=0, _1=620)
# Pandas(Index=10, _1=629)
# Pandas(Index=3453, _1=633)
# Pandas(Index=3457, _1=642)
# Pandas(Index=3459, _1=654)
# Pandas(Index=3460, _1=659)
# Pandas(Index=3467, _1=666)
# Pandas(Index=3468, _1=674)
# Pandas(Index=3475, _1=678)
# Pandas(Index=3476, _1=682)
# Pandas(Index=3477, _1=691)
# Pandas(Index=3479, _1=699)
# Pandas(Index=3481, _1=706)
# Pandas(Index=3483, _1=710)
# Pandas(Index=3525, _1=718)
# Pandas(Index=3526, _1=722)
# Pandas(Index=3530, _1=731)
# Pandas(Index=3531, _1=739)
# Pandas(Index=3534, _1=749)
# Pandas(Index=3610, _1=755)
# Pandas(Index=3612, _1=761)
# Pandas(Index=3654, _1=772)
# Pandas(Index=3658, _1=777)
# Pandas(Index=3661, _1=787)
# Pandas(Index=3664, _1=799)
# Pandas(Index=3675, _1=805)
# Pandas(Index=3678, _1=810)
# Pandas(Index=3683, _1=817)
# Pandas(Index=3923, _1=831)
# Pandas(Index=3927, _1=842)
# Pandas(Index=3935, _1=850)
# Pandas(Index=3957, _1=864)
# Pandas(Index=3965, _1=870)
# Pandas(Index=3966, _1=877)
# Pandas(Index=3975, _1=889)
# Pandas(Index=3979, _1=894)
# Pandas(Index=4017, _1=902)
# Pandas(Index=4021, _1=911)
# Pandas(Index=4022, _1=919)
# Pandas(Index=4023, _1=925)
# Pandas(Index=4025, _1=931)
# Pandas(Index=4029, _1=941)
# Pandas(Index=4030, _1=951)
# Pandas(Index=4031, _1=958)
# Pandas(Index=4035, _1=970)
# Pandas(Index=4038, _1=977)
# Pandas(Index=4042, _1=984)
# Pandas(Index=4043, _1=998)
# Pandas(Index=4044, _1=1007)
# Pandas(Index=4045, _1=1018)
# Pandas(Index=4052, _1=1031)
# Pandas(Index=4053, _1=1052)
# Pandas(Index=4054, _1=1067)
# Pandas(Index=4055, _1=1075)
# Pandas(Index=4095, _1=1082)
# Pandas(Index=4100, _1=1097)
# Pandas(Index=4102, _1=1113)
# Pandas(Index=4107, _1=1128)
# Pandas(Index=4110, _1=1134)
# Pandas(Index=4113, _1=1141)
# Pandas(Index=4117, _1=1157)
# Pandas(Index=4119, _1=1169)
# Pandas(Index=4122, _1=1176)
# Pandas(Index=4127, _1=1213)
# Pandas(Index=4129, _1=1220)
# Pandas(Index=4130, _1=1234)
# Pandas(Index=4133, _1=1257)
# Pandas(Index=4138, _1=1295)
# Pandas(Index=4156, _1=1304)
# Pandas(Index=4171, _1=1328)
# Pandas(Index=4176, _1=1344)
# Pandas(Index=4180, _1=1354)
# Pandas(Index=4181, _1=1366)
# Pandas(Index=4184, _1=1374)
# Pandas(Index=4185, _1=1415)
# Pandas(Index=4186, _1=1426)
# Pandas(Index=4188, _1=1474)
# Pandas(Index=4193, _1=1508)
# Pandas(Index=4251, _1=1532)
# Pandas(Index=4252, _1=1542)
# Pandas(Index=4256, _1=1570)
# Pandas(Index=4259, _1=1586)
# Pandas(Index=5122, _1=1604)
# Pandas(Index=5141, _1=1624)
# Pandas(Index=5142, _1=1637)
# Pandas(Index=5145, _1=1658)
# Pandas(Index=5218, _1=1675)
# Pandas(Index=5220, _1=1696)
# Pandas(Index=5223, _1=1771)
# Pandas(Index=5224, _1=1790)
# Pandas(Index=5227, _1=1814)
# Pandas(Index=5228, _1=1870)
# Pandas(Index=5250, _1=1911)
# Pandas(Index=5251, _1=1939)
# Pandas(Index=5289, _1=1954)
# Pandas(Index=5290, _1=1969)
# Pandas(Index=6208, _1=1987)
# Pandas(Index=6209, _1=1997)
# Pandas(Index=6211, _1=2011)
# Pandas(Index=6216, _1=2033)
# Pandas(Index=6220, _1=2066)
# Pandas(Index=6227, _1=2096)
# Pandas(Index=6249, _1=2111)
# Pandas(Index=6253, _1=2148)
# Pandas(Index=6254, _1=2176)
# Pandas(Index=6263, _1=2198)
# Pandas(Index=6264, _1=2223)
# Pandas(Index=6266, _1=2254)
# Pandas(Index=6269, _1=2267)
# Pandas(Index=6713, _1=2295)
# Pandas(Index=6715, _1=2317)
# Pandas(Index=6793, _1=2329)
# Pandas(Index=6797, _1=2350)
# Pandas(Index=6802, _1=2377)
# Pandas(Index=6805, _1=2399)
# Pandas(Index=6808, _1=2423)
# Pandas(Index=6809, _1=2444)
# Pandas(Index=6813, _1=2470)
# Pandas(Index=6835, _1=2501)
# Pandas(Index=6853, _1=2525)
# Pandas(Index=6866, _1=2546)
# Pandas(Index=6892, _1=2571)
# Pandas(Index=6975, _1=2596)
# Pandas(Index=6976, _1=2630)
# Pandas(Index=6980, _1=2646)
# Pandas(Index=6984, _1=2667)
# Pandas(Index=6990, _1=2683)
# Pandas(Index=6991, _1=2703)
# Pandas(Index=6997, _1=2728)
# Pandas(Index=7018, _1=2773)
# Pandas(Index=7020, _1=2796)
# Pandas(Index=7027, _1=2811)
# Pandas(Index=7030, _1=2846)
# Pandas(Index=7032, _1=2887)
# Pandas(Index=7034, _1=2910)
# Pandas(Index=7060, _1=2933)
# Pandas(Index=7061, _1=2955)
# Pandas(Index=7063, _1=2988)
# Pandas(Index=7066, _1=3031)
# Pandas(Index=7076, _1=3062)
# Pandas(Index=7078, _1=3098)
# Pandas(Index=7080, _1=3138)
# Pandas(Index=7081, _1=3184)
# Pandas(Index=7083, _1=3216)
# Pandas(Index=7085, _1=3248)
# Pandas(Index=7087, _1=3276)
# Pandas(Index=7097, _1=3321)
# Pandas(Index=7098, _1=3365)
# Pandas(Index=7099, _1=3418)
# Pandas(Index=7101, _1=3436)
# Pandas(Index=7102, _1=3461)
# Pandas(Index=7141, _1=3529)
# Pandas(Index=7142, _1=3568)
# Pandas(Index=7147, _1=3595)
# Pandas(Index=7156, _1=3658)
# Pandas(Index=7165, _1=3695)
# Pandas(Index=7170, _1=3744)
# Pandas(Index=7171, _1=3765)
# Pandas(Index=7175, _1=3788)
# Pandas(Index=7182, _1=3820)
# Pandas(Index=7183, _1=3855)
# Pandas(Index=7184, _1=3887)
# Pandas(Index=7185, _1=3943)
# Pandas(Index=7186, _1=3973)
# Pandas(Index=7187, _1=4006)
# Pandas(Index=7188, _1=4056)
# Pandas(Index=7191, _1=4124)
# Pandas(Index=7193, _1=4201)
# Pandas(Index=7194, _1=4227)
# Pandas(Index=7198, _1=4406)
# Pandas(Index=7204, _1=4439)
# Pandas(Index=7336, _1=4523)
# Pandas(Index=7339, _1=4548)
# Pandas(Index=7343, _1=4588)
# Pandas(Index=7348, _1=4629)
# Pandas(Index=7351, _1=4658)
# Pandas(Index=7354, _1=4692)
# Pandas(Index=7356, _1=4737)
# Pandas(Index=7361, _1=4781)
# Pandas(Index=7362, _1=4834)
# Pandas(Index=7365, _1=4890)
# Pandas(Index=7367, _1=4947)
# Pandas(Index=7370, _1=5002)
# Pandas(Index=7372, _1=5028)
# Pandas(Index=7373, _1=5097)
# Pandas(Index=7378, _1=5154)
# Pandas(Index=7380, _1=5224)
# Pandas(Index=7381, _1=5272)
# Pandas(Index=7382, _1=5357)
# Pandas(Index=7388, _1=5388)
# Pandas(Index=7391, _1=5442)
# Pandas(Index=7413, _1=5511)
# Pandas(Index=7415, _1=5564)
# Pandas(Index=7417, _1=5644)
# Pandas(Index=7425, _1=5689)
# Pandas(Index=7426, _1=5779)
# Pandas(Index=7439, _1=5867)
# Pandas(Index=7441, _1=5915)
# Pandas(Index=7445, _1=5953)
# Pandas(Index=7448, _1=6013)
# Pandas(Index=7452, _1=6095)
# Pandas(Index=7455, _1=6148)
# Pandas(Index=7822, _1=6188)
# Pandas(Index=7823, _1=6233)
# Pandas(Index=7824, _1=6341)
# Pandas(Index=7826, _1=6379)
# Pandas(Index=7827, _1=6419)
# Pandas(Index=7828, _1=6493)
# Pandas(Index=7829, _1=6782)
# Pandas(Index=7831, _1=6837)
# Pandas(Index=7834, _1=6958)
# Pandas(Index=7845, _1=7173)
# Pandas(Index=7846, _1=7259)
# Pandas(Index=7859, _1=7354)
# Pandas(Index=7860, _1=7445)
# Pandas(Index=7862, _1=7550)
# Pandas(Index=7863, _1=7629)
# Pandas(Index=7864, _1=7709)
# Pandas(Index=7879, _1=7946)
# Pandas(Index=7882, _1=8065)
# Pandas(Index=9801, _1=8106)
# Pandas(Index=11317, _1=8182)
# Pandas(Index=11318, _1=8250)
# Pandas(Index=11322, _1=8339)
# Pandas(Index=11325, _1=8398)
# Pandas(Index=11326, _1=8456)
# Pandas(Index=11328, _1=8531)
# Pandas(Index=11411, _1=8613)
# Pandas(Index=11414, _1=8694)
# Pandas(Index=11432, _1=8804)
# Pandas(Index=11435, _1=8865)
# Pandas(Index=11437, _1=8947)
# Pandas(Index=11442, _1=9022)
# Pandas(Index=11449, _1=9081)
# Pandas(Index=11454, _1=9150)
# Pandas(Index=11456, _1=9225)
# Pandas(Index=11461, _1=9300)
# Pandas(Index=11463, _1=9351)
# Pandas(Index=11465, _1=9405)
# Pandas(Index=11481, _1=9489)
# Pandas(Index=11485, _1=9589)
# Pandas(Index=11498, _1=9734)
# Pandas(Index=11591, _1=9893)
# Pandas(Index=11595, _1=9943)
# Pandas(Index=11601, _1=10009)
# Pandas(Index=11730, _1=10087)
# Pandas(Index=11760, _1=10168)
# Pandas(Index=11761, _1=10242)
# Pandas(Index=11763, _1=10299)
# Pandas(Index=11764, _1=10436)
# Pandas(Index=11765, _1=10650)
# Pandas(Index=11766, _1=10798)
# Pandas(Index=11772, _1=10891)
# Pandas(Index=11780, _1=10963)
# Pandas(Index=11785, _1=11051)
# Pandas(Index=11786, _1=11131)
# Pandas(Index=11787, _1=11206)
# Pandas(Index=11789, _1=11327)
# Pandas(Index=11790, _1=11402)
# Pandas(Index=11794, _1=11504)
# Pandas(Index=11796, _1=11582)
# Pandas(Index=11798, _1=11806)
# Pandas(Index=11800, _1=11902)
# Pandas(Index=11801, _1=12168)
# Pandas(Index=11820, _1=12375)
# Pandas(Index=12351, _1=12455)
# Pandas(Index=12358, _1=12528)
# Pandas(Index=12359, _1=12648)
# Pandas(Index=12360, _1=12717)
# Pandas(Index=12366, _1=12807)
# Pandas(Index=12391, _1=12889)
# Pandas(Index=12468, _1=12971)
# Pandas(Index=12478, _1=13043)
# Pandas(Index=12484, _1=13133)
# Pandas(Index=12485, _1=13218)
# Pandas(Index=12488, _1=13466)
# Pandas(Index=12547, _1=13560)

# %%
allTimeHigh
# Out:
# 13560
